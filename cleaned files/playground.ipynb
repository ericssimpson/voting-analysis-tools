# %%
import os
import pandas as pd
import lightgbm as lgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import os
#       2 import pandas as pd
# ----> 3 import lightgbm as lgb
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
# Function to load and preprocess data from CSV files
def load_and_preprocess_data(directory):
    feature_list = []
    ranking_list = []
    for file_name in os.listdir(directory):
        if file_name.endswith('.csv'):
            file_path = os.path.join(directory, file_name)
            data = pd.read_csv(file_path)
            features = data[['#candidates', 'type', 'level']].copy()
            features['num_voters'] = len(data)
            rankings = data['rankings']
            feature_list.append(features)
            ranking_list.append(rankings)
    # Combine all features and rankings into a single DataFrame
    combined_features = pd.concat(feature_list, ignore_index=True)
    combined_rankings = pd.concat(ranking_list, ignore_index=True)
    return combined_features, combined_rankings

# Function to train a ranking model
def train_ranking_model(features, rankings):
    train_data = lgb.Dataset(features, label=rankings)
    params = {
        'objective': 'lambdarank',
        'metric': 'ndcg',
        'ndcg_at': [5],  # Adjust based on your requirement
        'learning_rate': 0.1,
        'num_leaves': 31,
        'min_data_in_leaf': 20,
    }
    ranker = lgb.train(params, train_data, num_boost_round=100)
    return ranker

# Function to predict rankings for new data
def predict_rankings(model, features):
    predictions = model.predict(features)
    ranked_items = [sorted(range(len(p)), key=lambda i: p[i], reverse=True) for p in predictions]
    return ranked_items

# Function to save the predicted rankings to a new CSV file
def save_predictions(predictions, output_file_path):
    predictions_df = pd.DataFrame(predictions)
    predictions_df.to_csv(output_file_path, index=False)

# Main function to process all files in a directory and generate predictions
def main(input_directory, output_file_path):
    # Load and preprocess training data
    features, rankings = load_and_preprocess_data(input_directory)
    
    # Train the ranking model
    ranker = train_ranking_model(features, rankings)
    
    # Predict rankings for the features
    predictions = predict_rankings(ranker, features)
    
    # Save predictions to output file
    save_predictions(predictions, output_file_path)

# Directory containing the input CSV files and the output file path
input_directory = 'path/to/csv_files'
output_file_path = 'predicted_rankings.csv'

# Run the main function
main(input_directory, output_file_path)

# %% [markdown]
# NULL Elections

# %%
from null_elections import *

# %%
filename = "NewYorkCity_06222021_DEMComptrollerCitywide.csv"
runs = 1
sum_gamma = 0
for i in range(runs):
    gamma = get_null_gamma(filename, 'extreme')[1]
    sum_gamma += gamma

print(sum_gamma/runs)
# Out:
# c:\Users\mahsh\Documents\GitHub\bugs-in-democracy\cleaned files\MDS_analysis.py:162: RuntimeWarning: divide by zero encountered in true_divide
#   distance = 1 / np.sqrt(freq_upper_triangle)
# 0.1454041806551443

# %%
from rcv_distribution import *

# %%
ballots, candidates = parse_election_data("dataverse_files/NewYorkCity_06222021_DEMComptrollerCitywide.csv")

# %%
for b in ballots:
    print(b, ": ", ballots[b])
# Out:
# ('Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson', 'Kevin S. Parker') :  270
# ('Brad Lander', 'Kevin S. Parker', 'Reshma Patel') :  359
# ('Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson', 'Kevin S. Parker', 'Michelle Caruso-Cabrera') :  101
# ('Brad Lander', 'Corey D. Johnson') :  31875
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin') :  3666
# ('Corey D. Johnson',) :  65621
# ('Alex Pan', 'Corey D. Johnson', 'Brian A. Benjamin') :  64
# ('Brad Lander',) :  90049
# ('Kevin S. Parker',) :  17658
# ('Corey D. Johnson', 'Brad Lander', 'Michelle Caruso-Cabrera', 'David I. Weprin', 'Reshma Patel') :  66
# ('Brad Lander', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Reshma Patel') :  143
# ('Brad Lander', 'David I. Weprin', 'Brian A. Benjamin', 'Corey D. Johnson', 'Zach Iscol') :  59
# ('Brad Lander', 'Terri Liftin') :  535
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Reshma Patel') :  157
# ('Reshma Patel', 'Alex Pan', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'David I. Weprin') :  7
# ('Brian A. Benjamin', 'Brad Lander') :  2107
# ('Kevin S. Parker', 'Brian A. Benjamin', 'Corey D. Johnson') :  511
# ('Brad Lander', 'Kevin S. Parker', 'David I. Weprin', 'Reshma Patel', 'Corey D. Johnson') :  20
# ('Kevin S. Parker', 'Corey D. Johnson', 'Brad Lander') :  398
# ('Corey D. Johnson', 'Reshma Patel') :  2626
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Alex Pan', 'Terri Liftin') :  9
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Reshma Patel', 'Zach Iscol') :  533
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Zach Iscol', 'Reshma Patel') :  61
# ('Brad Lander', 'Brian A. Benjamin', 'Reshma Patel', 'Alex Pan') :  40
# ('Brad Lander', 'Reshma Patel') :  5734
# ('Brad Lander', 'Brian A. Benjamin') :  5368
# ('Corey D. Johnson', 'Brad Lander') :  11948
# ('Brad Lander', 'Kevin S. Parker', 'Corey D. Johnson', 'Brian A. Benjamin') :  114
# () :  171913
# ('Alex Pan', 'Michelle Caruso-Cabrera') :  573
# ('Zach Iscol', 'Terri Liftin', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  6
# ('Michelle Caruso-Cabrera', 'Terri Liftin', 'Corey D. Johnson', 'Brian A. Benjamin', 'Kevin S. Parker') :  131
# ('Brian A. Benjamin', 'Corey D. Johnson', 'Kevin S. Parker') :  699
# ('Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Zach Iscol') :  95
# ('David I. Weprin',) :  21401
# ('Michelle Caruso-Cabrera', 'Brad Lander') :  1931
# ('Michelle Caruso-Cabrera', 'David I. Weprin') :  1544
# ('David I. Weprin', 'Corey D. Johnson', 'Brad Lander') :  690
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel') :  3373
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'Alex Pan', 'Zach Iscol') :  53
# ('Brad Lander', 'Reshma Patel', 'Corey D. Johnson') :  2287
# ('Brad Lander', 'Zach Iscol', 'Corey D. Johnson') :  864
# ('Brad Lander', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  13
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera') :  7106
# ('Brad Lander', 'Zach Iscol', 'David I. Weprin', 'Corey D. Johnson') :  51
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'Corey D. Johnson') :  311
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  642
# ('Corey D. Johnson', 'Brad Lander', 'Zach Iscol') :  813
# ('Corey D. Johnson', 'Brad Lander', 'Brian A. Benjamin') :  1277
# ('David I. Weprin', 'Brad Lander') :  1704
# ('Corey D. Johnson', 'Terri Liftin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Alex Pan') :  8
# ('Reshma Patel', 'Brian A. Benjamin', 'Brad Lander', 'Michelle Caruso-Cabrera', 'Corey D. Johnson') :  14
# ('Brad Lander', 'Corey D. Johnson', 'Michelle Caruso-Cabrera') :  2975
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin') :  2863
# ('Brad Lander', 'Michelle Caruso-Cabrera') :  4612
# ('David I. Weprin', 'Kevin S. Parker') :  571
# ('David I. Weprin', 'Terri Liftin') :  255
# ('Terri Liftin',) :  2592
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'David I. Weprin', 'Kevin S. Parker') :  151
# ('Zach Iscol', 'Kevin S. Parker', 'Reshma Patel') :  19
# ('Brad Lander', 'David I. Weprin') :  3570
# ('Kevin S. Parker', 'Brian A. Benjamin', 'Brad Lander', 'Corey D. Johnson') :  57
# ('Brian A. Benjamin', 'Corey D. Johnson', 'Brad Lander') :  855
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Zach Iscol', 'Terri Liftin') :  191
# ('Brad Lander', 'David I. Weprin', 'Reshma Patel') :  276
# ('Brad Lander', 'David I. Weprin', 'Corey D. Johnson') :  1586
# ('Brad Lander', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Corey D. Johnson') :  43
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brad Lander') :  1017
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Corey D. Johnson') :  1629
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  72
# ('David I. Weprin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Zach Iscol', 'Corey D. Johnson') :  12
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Brian A. Benjamin', 'Zach Iscol', 'Corey D. Johnson') :  12
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Zach Iscol') :  179
# ('Brad Lander', 'Reshma Patel', 'Michelle Caruso-Cabrera') :  905
# ('Corey D. Johnson', 'Brad Lander', 'David I. Weprin', 'Brian A. Benjamin', 'Kevin S. Parker') :  234
# ('Corey D. Johnson', 'Brad Lander', 'Reshma Patel', 'Brian A. Benjamin') :  89
# ('Corey D. Johnson', 'David I. Weprin', 'Alex Pan', 'Zach Iscol', 'Brad Lander') :  3
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'Reshma Patel', 'Terri Liftin') :  54
# ('Alex Pan', 'David I. Weprin', 'Reshma Patel', 'Brian A. Benjamin', 'Kevin S. Parker') :  4
# ('Alex Pan', 'David I. Weprin', 'Kevin S. Parker', 'Brian A. Benjamin', 'Terri Liftin') :  1
# ('Brad Lander', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera') :  484
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'Terri Liftin') :  492
# ('Corey D. Johnson', 'Terri Liftin') :  340
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'David I. Weprin') :  459
# ('Brad Lander', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'Zach Iscol') :  38
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  360
# ('David I. Weprin', 'Zach Iscol') :  1213
# ('Zach Iscol',) :  7366
# ('Reshma Patel', 'Brian A. Benjamin', 'Kevin S. Parker', 'Corey D. Johnson', 'Michelle Caruso-Cabrera') :  32
# ('David I. Weprin', 'Corey D. Johnson') :  5396
# ('Brian A. Benjamin', 'Corey D. Johnson') :  3257
# ('Corey D. Johnson', 'David I. Weprin') :  5669
# ('Michelle Caruso-Cabrera',) :  38345
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Terri Liftin') :  11
# ('David I. Weprin', 'Reshma Patel', 'Brad Lander', 'Corey D. Johnson') :  18
# ('Corey D. Johnson', 'Brian A. Benjamin') :  3839
# ('Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Corey D. Johnson') :  285
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', '
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Alex Pan', 'Terri Liftin') :  68
# ('David I. Weprin', 'Kevin S. Parker', 'Brad Lander', 'Corey D. Johnson', 'Zach Iscol') :  8
# ('Zach Iscol', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Kevin S. Parker') :  4
# ('Brad Lander', 'Zach Iscol', 'Brian A. Benjamin') :  238
# ('Terri Liftin', 'Corey D. Johnson', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Zach Iscol') :  3
# ('Alex Pan', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Corey D. Johnson') :  5
# ('Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson', 'Zach Iscol') :  159
# ('Brian A. Benjamin', 'Zach Iscol', 'Reshma Patel', 'Brad Lander', 'David I. Weprin') :  4
# ('Corey D. Johnson', 'Brad Lander', 'Kevin S. Parker', 'David I. Weprin', 'Reshma Patel') :  57
# ('Reshma Patel', 'Corey D. Johnson') :  1267
# ('Kevin S. Parker', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'Terri Liftin', 'Alex Pan') :  14
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Reshma Patel', 'Alex Pan') :  55
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Reshma Patel', 'Zach Iscol', 'Brian A. Benjamin') :  29
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Brad Lander', 'Reshma Patel', 'Kevin S. Parker') :  35
# ('David I. Weprin', 'Zach Iscol', 'Terri Liftin', 'Brian A. Benjamin', 'Reshma Patel') :  5
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Reshma Patel', 'Terri Liftin') :  70
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Zach Iscol') :  174
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Zach Iscol', 'Reshma Patel', 'Brian A. Benjamin') :  17
# ('David I. Weprin', 'Michelle Caruso-Cabrera') :  1854
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brad Lander', 'Kevin S. Parker', 'Reshma Patel') :  67
# ('David I. Weprin', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'Terri Liftin') :  113
# ('Michelle Caruso-Cabrera', 'Zach Iscol', 'Brad Lander', 'Corey D. Johnson', 'David I. Weprin') :  66
# ('Reshma Patel', 'David I. Weprin', 'Kevin S. Parker') :  70
# ('Kevin S. Parker', 'Reshma Patel', 'Brian A. Benjamin') :  85
# ('Corey D. Johnson', 'Brad Lander', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Kevin S. Parker') :  62
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Zach Iscol') :  104
# ('Corey D. Johnson', 'Zach Iscol', 'Reshma Patel', 'David I. Weprin', 'Brian A. Benjamin') :  11
# ('Corey D. Johnson', 'Brad Lander', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  126
# ('Corey D. Johnson', 'Zach Iscol') :  1359
# ('Brad Lander', 'Reshma Patel', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  39
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'David I. Weprin') :  316
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Kevin S. Parker', 'David I. Weprin') :  221
# ('Alex Pan', 'Reshma Patel', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Kevin S. Parker') :  10
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'Brian A. Benjamin', 'Zach Iscol') :  87
# ('Corey D. Johnson', 'Brian A. Benjamin', 'Brad Lander', 'Reshma Patel') :  54
# ('Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Corey D. Johnson', 'Terri Liftin') :  8
# ('Michelle Caruso-Cabrera', 'Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Brian A. Benjamin') :  116
# ('Reshma Patel', 'Brian A. Benjamin') :  600
# ('Brad Lander', 'Reshma Patel', 'Corey D. Johnson', 'Kevin S. Parker') :  128
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'Michelle Caruso-Cabrera', 'Reshma Patel') :  139
# ('Terri Liftin', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'David I. Weprin', 'Brian A. Benjamin') :  64
# ('Corey D. Johnson', 'Alex Pan', 'Zach Iscol') :  25
# ('Brad Lander', 'Kevin S. Parker', 'Zach Iscol') :  120
# ('Zach Iscol', 'Kevin S. Parker', 'Brian A. Benjamin', 'Corey D. Johnson', 'Michelle Caruso-Cabrera') :  3
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Michelle Caruso-Cabrera') :  204
# ('Terri Liftin', 'Brad Lander', 'Brian A. Benjamin', 'Kevin S. Parker', 'David I. Weprin') :  2
# ('Reshma Patel', 'Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson') :  52
# ('Reshma Patel', 'Terri Liftin', 'David I. Weprin') :  35
# ('Brad Lander', 'Reshma Patel', 'Brian A. Benjamin', 'Corey D. Johnson') :  391
# ('Alex Pan', 'Corey D. Johnson', 'Reshma Patel') :  65
# ('Reshma Patel', 'Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin') :  54
# ('Zach Iscol', 'Corey D. Johnson', 'Terri Liftin', 'Brian A. Benjamin', 'Brad Lander') :  3
# ('Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel', 'Brad Lander', 'Alex Pan') :  22
# ('Brian A. Benjamin', 'Kevin S. Parker', 'Brad Lander', 'Michelle Caruso-Cabrera', 'Reshma Patel') :  28
# ('David I. Weprin', 'Brian A. Benjamin', 'Alex Pan', 'Brad Lander') :  1
# ('Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson', 'David I. Weprin') :  181
# ('Corey D. Johnson', 'Brad Lander', 'Brian A. Benjamin', 'David I. Weprin', 'Kevin S. Parker') :  83
# ('Brian A. Benjamin', 'Alex Pan', 'Zach Iscol', 'Brad Lander', 'Reshma Patel') :  3
# ('Reshma Patel', 'Brian A. Benjamin', 'Corey D. Johnson', 'Kevin S. Parker', 'Terri Liftin') :  7
# ('Brad Lander', 'Brian A. Benjamin', 'Reshma Patel') :  930
# ('David I. Weprin', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Zach Iscol', 'Corey D. Johnson') :  9
# ('Kevin S. Parker', 'Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Zach Iscol') :  25
# ('Brian A. Benjamin', 'Reshma Patel', 'David I. Weprin') :  50
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Kevin S. Parker') :  197
# ('Alex Pan', 'Reshma Patel', 'David I. Weprin', 'Brian A. Benjamin', 'Kevin S. Parker') :  17
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'Terri Liftin', 'Alex Pan') :  55
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  111
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Reshma Patel', 'David I. Weprin') :  8
# ('Brad Lander', 'Reshma Patel', 'David I. Weprin') :  384
# ('Brian A. Benjamin', 'Reshma Patel', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  10
# ('Michelle Caruso-Cabrera', 'Alex Pan', 'Corey D. Johnson', 'Zach Iscol', 'Brad Lander') :  6
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Zach Iscol') :  112
# ('Brad Lander', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'Reshma Patel') :  12
# ('Brian A. Benjamin', 'Reshma Patel') :  655
# ('Michelle Caruso-Cabrera', 'Terri Liftin', 'David I. Weprin', 'Kevin S. Parker') :  6
# ('Corey D. Johnson', 'Reshma Patel', 'Brad Lander', 'Brian A. Benjamin', 'David I. Weprin') :  17
# ('Corey D. Johnson', 'Reshma Patel', 'David I. Weprin') :  273
# ('David I. Weprin', 'Michelle Caruso-Cabrera', 'Brad Lander') :  145
# ('Reshma Patel', 'Corey D. Johnson', 'David I. Weprin', 'Brad Lander', 'Brian A. Benjamin') :  8
# ('David I. Weprin', 'Brad Lander', 'Michelle Caruso-Cabrera', '
michelle Caruso-Cabrera', 'Corey D. Johnson', 'Terri Liftin') :  25
# ('Brad Lander', 'Zach Iscol') :  2058
# ('David I. Weprin', 'Zach Iscol', 'Reshma Patel', 'Brian A. Benjamin', 'Corey D. Johnson') :  8
# ('Brad Lander', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  350
# ('Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Corey D. Johnson') :  315
# ('Brad Lander', 'Corey D. Johnson', 'David I. Weprin', 'Brian A. Benjamin') :  309
# ('David I. Weprin', 'Brian A. Benjamin', 'Brad Lander') :  178
# ('David I. Weprin', 'Zach Iscol', 'Terri Liftin') :  60
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Terri Liftin') :  12
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Michelle Caruso-Cabrera') :  329
# ('Corey D. Johnson', 'Terri Liftin', 'Reshma Patel') :  72
# ('Brad Lander', 'Reshma Patel', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Alex Pan') :  16
# ('Terri Liftin', 'David I. Weprin') :  169
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  21
# ('David I. Weprin', 'Corey D. Johnson', 'Reshma Patel', 'Terri Liftin') :  3
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'David I. Weprin', 'Reshma Patel') :  93
# ('Terri Liftin', 'Reshma Patel', 'Brian A. Benjamin', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  2
# ('Reshma Patel', 'Brad Lander', 'Corey D. Johnson', 'Terri Liftin', 'Kevin S. Parker') :  7
# ('Terri Liftin', 'David I. Weprin', 'Zach Iscol') :  17
# ('Brad Lander', 'Reshma Patel', 'Alex Pan', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera') :  12
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Brad Lander') :  575
# ('David I. Weprin', 'Corey D. Johnson', 'Reshma Patel') :  153
# ('Brad Lander', 'Reshma Patel', 'Terri Liftin') :  435
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'David I. Weprin', 'Brad Lander', 'Zach Iscol') :  3
# ('Michelle Caruso-Cabrera', 'Zach Iscol', 'David I. Weprin', 'Reshma Patel') :  71
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson') :  5609
# ('Kevin S. Parker', 'David I. Weprin', 'Alex Pan') :  19
# ('Corey D. Johnson', 'Brad Lander', 'Kevin S. Parker', 'Reshma Patel', 'Michelle Caruso-Cabrera') :  46
# ('Corey D. Johnson', 'David I. Weprin', 'Zach Iscol', 'Brian A. Benjamin', 'Reshma Patel') :  4
# ('Brad Lander', 'David I. Weprin', 'Zach Iscol') :  343
# ('Corey D. Johnson', 'Brad Lander', 'Reshma Patel', 'Zach Iscol') :  51
# ('Zach Iscol', 'Corey D. Johnson') :  1050
# ('David I. Weprin', 'Terri Liftin', 'Zach Iscol') :  52
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Alex Pan', 'Brad Lander') :  10
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Kevin S. Parker') :  247
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Reshma Patel', 'Kevin S. Parker') :  240
# ('Corey D. Johnson', 'Kevin S. Parker', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera', 'Brad Lander') :  120
# ('Brad Lander', 'Corey D. Johnson', 'Terri Liftin', 'Reshma Patel') :  928
# ('Brian A. Benjamin', 'Terri Liftin', 'Corey D. Johnson') :  37
# ('David I. Weprin', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'Zach Iscol') :  15
# ('Brad Lander', 'Corey D. Johnson', 'Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel') :  309
# ('Brad Lander', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'David I. Weprin', 'Zach Iscol') :  79
# ('David I. Weprin', 'Zach Iscol', 'Corey D. Johnson') :  286
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brad Lander', 'Zach Iscol') :  58
# ('David I. Weprin', 'Brad Lander', 'Brian A. Benjamin', 'Terri Liftin', 'Michelle Caruso-Cabrera') :  9
# ('Alex Pan', 'David I. Weprin', 'Michelle Caruso-Cabrera') :  34
# ('Brian A. Benjamin', 'Reshma Patel', 'Terri Liftin', 'David I. Weprin') :  3
# ('David I. Weprin', 'Brian A. Benjamin', 'Reshma Patel', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  12
# ('Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Zach Iscol', 'Corey D. Johnson', 'Reshma Patel') :  14
# ('Reshma Patel', 'Terri Liftin', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'Corey D. Johnson') :  7
# ('Zach Iscol', 'David I. Weprin') :  996
# ('Corey D. Johnson', 'David I. Weprin', 'Michelle Caruso-Cabrera') :  555
# ('Brad Lander', 'Kevin S. Parker', 'Corey D. Johnson', 'Reshma Patel', 'David I. Weprin') :  45
# ('Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Kevin S. Parker', 'Reshma Patel', 'Alex Pan') :  46
# ('Brad Lander', 'Terri Liftin', 'Corey D. Johnson') :  142
# ('Zach Iscol', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Reshma Patel') :  425
# ('Brian A. Benjamin', 'Alex Pan', 'Reshma Patel') :  39
# ('Brad Lander', 'Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel', 'Terri Liftin') :  30
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Brian A. Benjamin', 'Alex Pan') :  35
# ('Reshma Patel', 'Terri Liftin', 'Alex Pan', 'Corey D. Johnson', 'Brian A. Benjamin') :  7
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'David I. Weprin') :  474
# ('David I. Weprin', 'Reshma Patel', 'Brian A. Benjamin', 'Corey D. Johnson', 'Zach Iscol') :  6
# ('Brad Lander', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Zach Iscol', 'David I. Weprin') :  96
# ('Zach Iscol', 'Corey D. Johnson', 'Brad Lander', 'David I. Weprin', 'Michelle Caruso-Cabrera') :  18
# ('Corey D. Johnson', 'Brad Lander', 'Reshma Patel', 'Brian A. Benjamin', 'Kevin S. Parker') :  147
# ('Alex Pan', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'David I. Weprin') :  4
# ('Brad Lander', 'Reshma Patel', 'Brian A. Benjamin', 'Kevin S. Parker', 'Alex Pan') :  33
# ('Brad Lander', 'Brian A. Benjamin', 'Zach Iscol', 'Reshma Patel', 'Corey D. Johnson') :  45
# ('Corey D. Johnson', 'Reshma Patel', 'Alex Pan') :  87
# ('Terri Liftin', 'Michelle Caruso-Cabrera') :  283
# ('Reshma Patel', 'Alex Pan', 'Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson') :  3
# ('Corey D. Johnson', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'Kevin S. Parker', 'Brian A. Benjamin') :  48
# ('Corey D. Johnson', 'David I. Weprin', 'Brad Lander', 'Alex Pan', 'Kevin S. Parker') :  5
# ('Corey D. Johnson', 'Brad Lander', 'Zach Iscol', 'Brian A. Benjamin', 'David I. Weprin') :  35
# ('Brad Lander', 'Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel') :  89
# ('Reshma Patel', 'Michelle Caruso-Cabrera', 'Alex Pan', 'Corey D. Johnson', 'Terri Liftin') :  27
# ('Corey D. Johnson', 'Brad Lander', 'Brian A. Benjamin', 'Kevin S. Parker') :  194
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  135
# ('Brad Lander', 'Reshma Patel', 'Brian A. Benjamin', 'Alex Pan', 'Michelle Caruso-Cabrera') :  15
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Brian A. Benjamin') :  137
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Kevin S. Parker', 'Alex Pan') :  194
# ('Corey D. Johnson', 'Kevin S. Parker') :  3717
# ('Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel') :  312
# ('Terri Liftin', 'Corey D. Johnson', 'Kevin S. Parker') :  30
# ('Brad Lander', 'Brian A. Benjamin', 'Kevin S. Parker', 'Zach Iscol', 'Reshma Patel') :  29
# ('Corey D. Johnson', 'David I. Weprin', 'Brad Lander', 'Michelle Caruso-Cabrera', 'Terri Liftin') :  14
# ('Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Terri Liftin', 'Alex Pan') :  92
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera') :  148
# ('Zach Iscol', 'Brian A. Benjamin', 'Reshma Patel', 'Michelle Caruso-Cabrera', 'David I. Weprin') :  3
# ('Brad Lander', 'Brian A. Benjamin', 'Corey D. Johnson', 'Terri Liftin', 'Kevin S. Parker') :  27
# ('Michelle Caruso-Cabrera', 'Terri Liftin', 'Reshma Patel', 'Alex Pan', 'Brian A. Benjamin') :  40
# ('Reshma Patel', 'Corey D. Johnson', 'Brad Lander', 'Brian A. Benjamin', 'Zach Iscol') :  11
# ('Brad Lander', 'Michelle Caruso-Cabrera', 'Kevin S. Parker', 'Reshma Patel', 'Terri Liftin') :  17
# ('Corey D. Johnson', 'Kevin S. Parker', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  74
# ('Kevin S. Parker', 'David I. Weprin', 'Zach Iscol', 'Corey D. Johnson', 'Brian A. Benjamin') :  2
# ('Brad Lander', 'Terri Liftin', 'Zach Iscol', 'Brian A. Benjamin', 'Corey D. Johnson') :  3
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Corey D. Johnson', 'Terri Liftin', 'Kevin S. Parker') :  13
# ('Brad Lander', 'Reshma Patel', 'David I. Weprin', 'Brian A. Benjamin', 'Michelle Caruso-Cabrera') :  20
# ('Alex Pan', 'Kevin S. Parker', 'Brad Lander', 'Reshma Patel', 'Corey D. Johnson') :  1
# ('Terri Liftin', 'Kevin S. Parker', 'Brad Lander') :  7
# ('Corey D. Johnson', 'David I. Weprin', 'Brad Lander', 'Kevin S. Parker') :  47
# ('Zach Iscol', 'Brian A. Benjamin', 'David I. Weprin', 'Michelle Caruso-Cabrera') :  4
# ('Michelle Caruso-Cabrera', 'Terri Liftin', 'Corey D. Johnson', 'Brian A. Benjamin', 'Alex Pan') :  43
# ('Michelle Caruso-Cabrera', 'Zach Iscol', 'David I. Weprin', 'Brad Lander') :  9
# ('Brad Lander', 'David I. Weprin', 'Brian A. Benjamin', 'Corey D. Johnson', 'Reshma Patel') :  22
# ('Brad Lander', 'Reshma Patel', 'David I. Weprin', 'Brian A. Benjamin', 'Zach Iscol') :  20
# ('Brian A. Benjamin', 'Reshma Patel', 'Brad Lander', 'David I. Weprin') :  11
# ('Brad Lander', 'Corey D. Johnson', 'Reshma Patel', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  81
# ('Brian A. Benjamin', 'David I. Weprin', 'Corey D. Johnson') :  169
# ('Kevin S. Parker', 'Brian A. Benjamin', 'Reshma Patel', 'Corey D. Johnson', 'Terri Liftin') :  12
# ('Reshma Patel', 'Brad Lander') :  1254
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Corey D. Johnson', 'Terri Liftin') :  6
# ('Reshma Patel', 'Brad Lander', 'Corey D. Johnson') :  454
# ('Reshma Patel', 'Michelle Caruso-Cabrera') :  1830
# ('Reshma Patel', 'Brad Lander', 'Terri Liftin', 'Kevin S. Parker') :  9
# ('Reshma Patel', 'Brad Lander', 'Brian A. Benjamin', 'Zach Iscol', 'Michelle Caruso-Cabrera') :  12
# ('Brad Lander', 'Corey D. Johnson', 'Zach Iscol', 'Brian A. Benjamin', 'Reshma Patel') :  86
# ('Zach Iscol', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'Reshma Patel') :  7
# ('Zach Iscol', 'Brad Lander', 'Alex Pan') :  15
# ('Michelle Caruso-Cabrera', 'Zach Iscol', 'Reshma Patel', 'Alex Pan') :  10
# ('Brad Lander', 'Corey D. Johnson', 'Michelle Caruso-Cabrera', 'Reshma Patel', 'Alex Pan') :  107
# ('Brad Lander', 'Zach Iscol', 'Corey D. Johnson', 'Reshma Patel', 'David I. Weprin') :  37
# ('Michelle Caruso-Cabrera', 'Zach Iscol', 'Brian A. Benjamin') :  89
# ('Michelle Caruso-Cabrera', 'David I. Weprin', 'Corey D. Johnson') :  274
# ('Michelle Caruso-Cabrera', 'Terri Liftin') :  842
# ('Brad Lander', 'David I. Weprin', 'Corey D. Johnson', 'Brian A. Benjamin', 'Terri Liftin') :  14
# ('Zach Iscol', 'Terri Liftin') :  160
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'Brad Lander') :  6
# ('Zach Iscol', 'Reshma Patel', 'Corey D. Johnson') :  55
# ('David I. Weprin', 'Corey D. Johnson', 'Kevin S. Parker') :  186
# ('David I. Weprin', 'Corey D. Johnson', 'Brian A. Benjamin', 'Brad Lander', 'Zach Iscol') :  19
# ('Corey D. Johnson', 'Reshma Patel', 'Brad Lander', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin') :  38
# ('Brad Lander', 'Corey D. Johnson', 'Kevin S. Parker') :  1825
# ('Michelle Caruso-Cabrera', 'Alex Pan', 'Terri Liftin') :  30
# ('Brad Lander', 'Reshma Patel', 'David I. Weprin', 'Corey D. Johnson') :  71
# ('Zach Iscol', 'Terri Liftin', 'Michelle Caruso-Cabrera', 'Brian A. Benjamin', 'Alex Pan') :  3
# ('Brad Lander', 'Alex Pan', 'Reshma Patel', 'Michelle Caruso-Cabrera') :  15
# ('Michelle Caruso-Cabrera', 'Kevin S. Parker', 'Zach Iscol', 'Reshma Patel') :  8
# ('Brad Lander', 'David I. Weprin', 'Brian A. Benjamin', 'Reshma Patel', 'Michelle Caruso-Cabrera') :  16
# ('David I. Weprin', 'Corey D. Johnson', 'Brian A. Benjamin') :  321
# ('Brian A. Benjamin', 'Kevin S. Parker', 'Reshma Patel', 'Corey D. Johnson', 'Brad Lander') :  58
# ('Reshma Patel', 'Terri Liftin', 'Zach Iscol', 'David I. Weprin', 'Kevin S. Parker') :  3
# ('David I. Weprin', 'Zach Iscol', 'Michelle Caruso-Cabrera', 'Terri Liftin', 'Brian A. Benjamin') :  23
# ('Corey D. Johnson', 'David I. Weprin', 'Zach Iscol') :  293
# ('David I. Weprin', 'Brad Lander', 'Zach Iscol') :  197
# ('Brian A. Benjamin', 'David I. Weprin', 'Corey D. Johnson', 'Michelle Caruso-Cabrera') :  14
# ('Brian A. Benjamin', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Corey D. Johnson') :  11
# ('Reshma Patel', 'Brian A. Benjamin', 'Kevin S. Parker', 'Corey D. Johnson', 'Brad Lander') :  19
# ('Corey D. Johnson', 'Brad Lander', 'Michelle Caruso-Cabrera', 'Zach Iscol', 
# ('Alex Pan', 'Zach Iscol', 'Kevin S. Parker', 'Brad Lander', 'Brian A. Benjamin') :  1
# ('Terri Liftin', 'Corey D. Johnson', 'David I. Weprin', 'Kevin S. Parker', 'Brad Lander') :  1
# ('Zach Iscol', 'Reshma Patel', 'Terri Liftin', 'Brad Lander', 'Alex Pan') :  1
# ('Zach Iscol', 'Terri Liftin', 'David I. Weprin', 'Corey D. Johnson', 'Brad Lander') :  1
# ('Reshma Patel', 'David I. Weprin', 'Michelle Caruso-Cabrera', 'Brad Lander', 'Zach Iscol') :  1

# %%
from itertools import permutations
from collections import defaultdict

def generate_and_group_permutations(items):
    n = len(items)
    grouped_permutations = defaultdict(list)
    
    for i in range(1, n + 1):
        for perm in permutations(items, i):
            grouped_permutations[perm[0]].append(perm)
    
    return grouped_permutations

# Example usage
items = ['a','b', 'c', 'd']
grouped_permutations = generate_and_group_permutations(items)
print(grouped_permutations['a'])
# Out:
# [('a',), ('a', 'b'), ('a', 'c'), ('a', 'd'), ('a', 'b', 'c'), ('a', 'b', 'd'), ('a', 'c', 'b'), ('a', 'c', 'd'), ('a', 'd', 'b'), ('a', 'd', 'c'), ('a', 'b', 'c', 'd'), ('a', 'b', 'd', 'c'), ('a', 'c', 'b', 'd'), ('a', 'c', 'd', 'b'), ('a', 'd', 'b', 'c'), ('a', 'd', 'c', 'b')]

# %%
filename = "Maine_11082022_CongressionalDistrict2.csv"
runs = 5
sum_gamma = 0
for i in range(runs):
    gamma = get_null_gamma(filename)[1]
    sum_gamma += gamma

print(sum_gamma/runs)
# Out:
# getting null gamma for:  Maine_11082022_CongressionalDistrict2.csv
# Maine_11082022_CongressionalDistrict2.csv   normalized distances:  {'Golden, Jared Forrest': 2.0, 'Bond, Tiffany': 1.1196740122625028, 'Poliquin, Bruce': 0.0}
# getting null gamma for:  Maine_11082022_CongressionalDistrict2.csv
# Maine_11082022_CongressionalDistrict2.csv   normalized distances:  {'Golden, Jared Forrest': 2.0, 'Bond, Tiffany': 1.1196740122625028, 'Poliquin, Bruce': 0.0}
# getting null gamma for:  Maine_11082022_CongressionalDistrict2.csv
# Maine_11082022_CongressionalDistrict2.csv   normalized distances:  {'Golden, Jared Forrest': 2.0, 'Bond, Tiffany': 1.1196740122625028, 'Poliquin, Bruce': 0.0}
# getting null gamma for:  Maine_11082022_CongressionalDistrict2.csv
# Maine_11082022_CongressionalDistrict2.csv   normalized distances:  {'Golden, Jared Forrest': 2.0, 'Bond, Tiffany': 1.1196740122625028, 'Poliquin, Bruce': 0.0}
# getting null gamma for:  Maine_11082022_CongressionalDistrict2.csv
# Maine_11082022_CongressionalDistrict2.csv   normalized distances:  {'Golden, Jared Forrest': 2.0, 'Bond, Tiffany': 1.1196740122625028, 'Poliquin, Bruce': 0.0}
# 0.8143822308575466

# %%
directory = "null_elections"
csv = os.path.join(directory, filename) 
df = pd.read_csv(csv)
candidates = df['candidate'].values
print(candidates)
# Out:
# ['REP Poliquin, Bruce' 'DEM Golden, Jared F.' 'Bond, Tiffany L.'
#  'Hoar, William R.S.']

# %%
import sys
# !{sys.executable} -m pip install python-constraint
# Out:
# Collecting python-constraint
#   Downloading python-constraint-1.4.0.tar.bz2 (18 kB)
# Building wheels for collected packages: python-constraint
#   Building wheel for python-constraint (setup.py): started
#   Building wheel for python-constraint (setup.py): finished with status 'done'
#   Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24081 sha256=2cdd4dc30c8fd4c63336be621649299cd1924a9abcaa85b201d86051b245b4ae
#   Stored in directory: c:\users\mahsh\appdata\local\pip\cache\wheels\51\36\1f\c2ccb8dc4eba38c5215636d4ae2c480b32069cab0376bcc1a4
# Successfully built python-constraint
# Installing collected packages: python-constraint
# Successfully installed python-constraint-1.4.0

# %%
from constraint import Problem, AllDifferentConstraint

def find_all_solutions_cp(Va, Vb, Vc, len_1, len_2, len_3, max_value):
    problem = Problem()

    # Add variables with their respective domains
    problem.addVariables(['a1', 'a2', 'a3', 'a4', 'a5'], range(max_value + 1))
    problem.addVariables(['b1', 'b2', 'b3', 'b4', 'b5'], range(max_value + 1))
    problem.addVariables(['c1', 'c2', 'c3', 'c4', 'c5'], range(max_value + 1))

    # Add constraints
    problem.addConstraint(lambda a1, a2, a3, a4, a5: a1 + a2 + a3 + a4 + a5 == Va, ['a1', 'a2', 'a3', 'a4', 'a5'])
    problem.addConstraint(lambda b1, b2, b3, b4, b5: b1 + b2 + b3 + b4 + b5 == Vb, ['b1', 'b2', 'b3', 'b4', 'b5'])
    problem.addConstraint(lambda c1, c2, c3, c4, c5: c1 + c2 + c3 + c4 + c5 == Vc, ['c1', 'c2', 'c3', 'c4', 'c5'])

    problem.addConstraint(lambda a1, b1, c1: a1 + b1 + c1 == len_1, ['a1', 'b1', 'c1'])
    problem.addConstraint(lambda a2, a3, b2, b3, c2, c3: a2 + a3 + b2 + b3 + c2 + c3 == len_2, ['a2', 'a3', 'b2', 'b3', 'c2', 'c3'])
    problem.addConstraint(lambda a4, a5, b4, b5, c4, c5: a4 + a5 + b4 + b5 + c4 + c5 == len_3, ['a4', 'a5', 'b4', 'b5', 'c4', 'c5'])

    # Find all solutions
    solutions = problem.getSolutions()

    return solutions

# Example usage with arbitrary values and a maximum value bound
Va = 9
Vb = 7
Vc = 3
len_1 = 5
len_2 = 8
len_3 = 6
max_value = 10

solutions = find_all_solutions_cp(Va, Vb, Vc, len_1, len_2, len_3, max_value)
print(f"Found {len(solutions)} solutions.")
for sol in solutions:
    print(sol)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <cell line: 34>()
#      31 len_3 = 6
#      32 max_value = 10
# ---> 34 solutions = find_all_solutions_cp(Va, Vb, Vc, len_1, len_2, len_3, max_value)
#      35 print(f"Found {len(solutions)} solutions.")
#      36 for sol in solutions:
#
# Input In [30], in find_all_solutions_cp(Va, Vb, Vc, len_1, len_2, len_3, max_value)
#      18 problem.addConstraint(lambda a4, a5, b4, b5, c4, c5: a4 + a5 + b4 + b5 + c4 + c5 == len_3, ['a4', 'a5', 'b4', 'b5', 'c4', 'c5'])
#      20 # Find all solutions
# ---> 21 solutions = problem.getSolutions()
#      23 return solutions
#
# File c:\Users\mahsh\anaconda3\lib\site-packages\constraint\__init__.py:271, in Problem.getSolutions(self)
#     269 if not domains:
#     270     return []
# --> 271 return self._solver.getSolutions(domains, constraints, vconstraints)
#
# File c:\Users\mahsh\anaconda3\lib\site-packages\constraint\__init__.py:567, in BacktrackingSolver.getSolutions(self, domains, constraints, vconstraints)
#     566 def getSolutions(self, domains, constraints, vconstraints):
# --> 567     return list(self.getSolutionIter(domains, constraints, vconstraints))
#
# File c:\Users\mahsh\anaconda3\lib\site-packages\constraint\__init__.py:544, in BacktrackingSolver.getSolutionIter(self, domains, constraints, vconstraints)
#     541         domain.pushState()
#     543 for constraint, variables in vconstraints[variable]:
# --> 544     if not constraint(variables, domains, assignments, pushdomains):
#     545         # Value is not good.
#     546         break
#     547 else:
#
# File c:\Users\mahsh\anaconda3\lib\site-packages\constraint\__init__.py:991, in FunctionConstraint.__call__(self, variables, domains, assignments, forwardcheck, _unassigned)
#     986 missing = parms.count(_unassigned)
#     987 if missing:
#     988     return (self._assigned or self._func(*parms)) and (
#     989         not forwardcheck or
#     990         missing != 1 or
# --> 991         self.forwardCheck(variables, domains, assignments)
#     992     )
#     993 return self._func(*parms)
#
# File c:\Users\mahsh\anaconda3\lib\site-packages\constraint\__init__.py:921, in Constraint.forwardCheck(self, variables, domains, assignments, _unassigned)
#     902 """
#     903 Helper method for generic forward checking
#     904
#    (...)
#     918 @rtype: bool
#     919 """
#     920 unassignedvariable = _unassigned
# --> 921 for variable in variables:
#     922     if variable not in assignments:
#     923         if unassignedvariable is _unassigned:
#
# KeyboardInterrupt:

# %%
import pulp
import random

# Example parameters (replace with your actual values)
Va = 9
Vb = 7
Vc = 3
len_1 = 5
len_2 = 8
len_3 = 6


# Initialize the LP problem
prob = pulp.LpProblem("RandomizedIntegerSolution", pulp.LpMaximize)

# Define variables
a = pulp.LpVariable.dicts('a', range(1, 6), lowBound=0, cat='Integer')
b = pulp.LpVariable.dicts('b', range(1, 6), lowBound=0, cat='Integer')
c = pulp.LpVariable.dicts('c', range(1, 6), lowBound=0, cat='Integer')

# Objective function (not really needed for feasibility check)
prob += 0

# Constraints
prob += pulp.lpSum(a[i] for i in range(1, 6)) == Va
prob += pulp.lpSum(b[i] for i in range(1, 6)) == Vb
prob += pulp.lpSum(c[i] for i in range(1, 6)) == Vc

prob += a[1] + b[1] + c[1] == len_1
prob += a[2] + a[3] + b[2] + b[3] + c[2] + c[3] == len_2
prob += a[4] + a[5] + b[4] + b[5] + c[4] + c[5] == len_3

# Number of randomized runs to attempt
num_runs = 10

# List to store all found solutions
all_solutions = []

# Solve the problem multiple times with random initial values
for _ in range(num_runs):
    # Randomly initialize variables
    random.seed()  # Use current system time as seed for randomness
    for i in range(1, 6):
        a[i].setInitialValue(random.randint(0, Va))
        b[i].setInitialValue(random.randint(0, Vb))
        c[i].setInitialValue(random.randint(0, Vc))

    # Solve the problem
    prob.solve()

    # Store the solution if optimal
    if pulp.LpStatus[prob.status] == "Optimal":
        solution = [(int(a[i].value()), int(b[i].value()), int(c[i].value())) for i in range(1, 6)]
        all_solutions.append(solution)

# Print all found solutions
if all_solutions:
    for idx, solution in enumerate(all_solutions):
        print(f"Solution {idx + 1}:")
        for i in range(5):
            print(f"a[{i + 1}] = {solution[i][0]}, b[{i + 1}] = {solution[i][1]}, c[{i + 1}] = {solution[i][2]}")
        print()
else:
    print("No optimal solutions found in the given number of runs.")
# Out:
# Solution 1:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 2:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 3:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 4:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 5:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 6:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 7:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 8:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 9:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
#
# Solution 10:
# a[1] = 1, b[1] = 1, c[1] = 3
# a[2] = 8, b[2] = 0, c[2] = 0
# a[3] = 0, b[3] = 0, c[3] = 0
# a[4] = 0, b[4] = 6, c[4] = 0
# a[5] = 0, b[5] = 0, c[5] = 0
