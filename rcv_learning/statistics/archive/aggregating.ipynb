# %%
import pandas as pd

election_table_2 = pd.read_csv('election_table_2.csv')

# Group by the columns 'type', 'candidates', 'partisan', and 'level'
grouped_table_2 = election_table_2.groupby(['type', 'partisan', 'level']).agg({
    'gamma bf': ['mean', 'std'],
    'gamma mds': ['mean', 'std'],
    'bimodality': ['mean', 'std'],
    'filename': 'count'  # to get the total number of elections
}).reset_index()

# Rename columns for better readability
grouped_table_2.columns = ['type', 'partisan', 'level', 
                          'mean gamma bf', 'std gamma bf', 
                          'mean gamma mds', 'std gamma mds', 
                          'mean bimodality', 'std bimodality', 
                          'total number of elections']

grouped_table_2.head()
# Out:
#   type partisan  level  mean gamma bf  std gamma bf  mean gamma mds  \
# 0    B        0    1.0       0.823914      0.171755        0.772887
# 1    E        0    1.0       0.790054      0.163799        0.662145
# 2    E        1    1.0       0.607429      0.106381        0.664044
# 3    E        1    2.0       0.571424      0.379285        0.528075
# 4    E       DP    1.0       0.631044      0.161135        0.576450
#
#    std gamma mds  mean bimodality  std bimodality  total number of elections
# 0       0.194502         0.568078        0.268363                         96
# 1       0.186131         0.484952        0.295254                         29
# 2       0.086700         0.598989        0.124997                          4
# 3       0.306087         0.754339        0.203631                          2
# 4       0.172108         0.387086        0.143257                          6

# %%
file_path = 'aggregated_election_table_3.csv'
grouped_table_2.to_csv(file_path, index=False)
