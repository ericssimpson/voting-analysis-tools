# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.DataFrame(columns= ['candidates', 'choices', 'gamma', 'partisan'])
print(df)
# Out:
# Empty DataFrame
# Columns: [candidates, choices, gamma, partisan]
# Index: []

# %%
elections = pd.read_csv("election_table_2.csv")
d = {}
for i, row in elections.iterrows():
    partisan = None
    primary = False
    if row["partisan"] == '0':
        partisan = False
    elif row["partisan"] == '1':
        partisan = True 
    else:
        primary = True 
    
    if primary is False and row["candidates"] < 20:
        gamma = row["gamma mds"]
        choices = row["choices"]
        candidates = row['candidates']
        df.loc[len(df)] = [candidates, choices, gamma, partisan]

# %%
print(df)
# Out:
#      candidates  choices     gamma  partisan
# 0             3        4  0.955330      True
# 1             4        5  0.744512      True
# 2             2        3  1.000000      True
# 3             2        3  1.000000      True
# 4             2        3  1.000000      True
# ..          ...      ...       ...       ...
# 328           7        5  0.564615     False
# 329           6        4  0.576512     False
# 330           3        3  0.793754     False
# 331           7        7  0.168044     False
# 332           3        3  0.832061     False
#
# [333 rows x 4 columns]

# %%
sns.violinplot(data=df, x='candidates', y='gamma', hue='partisan', split=True)
# Out:
# <Axes: xlabel='candidates', ylabel='gamma'>

# %%
sns.violinplot(data=df, x='choices', y='gamma', hue='partisan', split=True)
# Out:
# <Axes: xlabel='choices', ylabel='gamma'>

# %%
sns.boxplot(data=df, x='choices', y='gamma', hue='partisan')
# Out:
# <Axes: xlabel='choices', ylabel='gamma'>

# %%
sns.boxenplot(data=df, x='candidates', y='gamma', hue='partisan')
# Out:
# <Axes: xlabel='candidates', ylabel='gamma'>
